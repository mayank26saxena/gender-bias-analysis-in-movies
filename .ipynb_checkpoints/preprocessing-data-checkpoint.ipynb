# %%
import os
from fnmatch import fnmatch
import pandas as pd
import cv2

def convert_bytes(num):
    """
    this function will convert bytes to MB.... GB... etc
    """
    for x in ['bytes', 'KB', 'MB', 'GB', 'TB']:
        if num < 1024.0:
            return "%3.1f %s" % (num, x)
        num /= 1024.0


def file_size(file_path):
    """
    this function will return the file size
    """
    if os.path.isfile(file_path):
        file_info = os.stat(file_path)
        #return convert_bytes(file_info.st_size)
        return file_info.st_size

# %%
root = '/home/mayank/Desktop/gender-bias-detection/official-trailers/'
pattern = "*.mp4"

columns = ['path', 'filename','movie-name', 'year-of-release', 'size', 'trailer', 'movie']

df = pd.DataFrame(columns=columns)

for path, subdirs, files in os.walk(root):
    for name in files:
        if fnmatch(name, pattern):
            
            # filename = os.path.join(path, name)
            # print('filename', filename)
            # print('filename type', type(filename))
            # print('path', path)
            # print('path type', type(path))
            # print('files', files)
            # print('files type', type(files))
            # print('files[0]', files[0])
            # break
            
            p = os.path.join(path, name)
            filename = files[0]
            year = filename.split('-')[0]
            movie_name = filename.split('-')[1]
            movie_name = movie_name.split('.')[0]
            size = file_size(p)
            if (size < 5e+7) :
                trailer = 1
                movie = 0
            else :
                trailer = 0
                movie = 1
                 
            df.loc[df.shape[0]] = [p, filename, movie_name, year, size, trailer, movie] 
           
            
df.head()

df.to_csv('/home/mayank/Desktop/gender-bias-detection/trailers_info.csv')

# %%
base_path = '/home/mayank/Desktop/gender-bias-detection/trailer-frames/'

frames_processed = 0 

for index, row in df.iterrows():
    if (row[5] == 1):
        #print('index', index)
        #print('row', row[1].split('.')[0])
        folder_path = row[1].split('.')[0]
        new_frames_folder_path = base_path + folder_path + "/"
        
        print('new_frames_folder_path', new_frames_folder_path)
    
        if not os.path.exists(new_frames_folder_path):
            os.makedirs(new_frames_folder_path)
        
            print('row0', row[0])
            vidcap = cv2.VideoCapture(row[0])
            success,image = vidcap.read()
            count = 0
            success = True
            while success:
                success,image = vidcap.read()
  
                if success :
                    #print ('Read a new frame: ', success)
                    frames_processed = frames_processed + 1
                    if (frames_processed % 25 == 0):
                        cv2.imwrite(new_frames_folder_path + "frame%d.jpg" % count, image)     # save frame as JPEG file
                        print('count', count)
                        print('Movie', row[1].split('.')[0])
        
                        count += 1
# Out:
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2014-dedh_ishqiya/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2010-love_sex_aur_dhokha/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2017-newton/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2010-band_baaja_baaraat/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2016-the_blueberry_hunt/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2009-tum_mile/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2012-chal_pichchur_banate_hai/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2015-second_half_husband/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2008-mumbai_meri_jaan/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2013-super_model/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2013-listen_amaya/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2016-ki_&_ka/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2009-karma_aur_holi/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2013-raanjhanaa/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2015-talvar/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2010-jhootha_hi_sahi/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2011-thank_you/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2014-riyasat/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2015-katti_batti/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2011-loot/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2013-himmatwala/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2016-a_flying_jatt/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2010-mallika/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2012-ajab_gazabb_love/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2017-mangal_ho/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2013-saare_jahaan_se_mehnga/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2012-joker/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2011-7_khoon_maaf/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2017-bhanwarey/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2017-omerta/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2014-ankhon_dekhi/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2017-raees/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2014-manjunath/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2012-cigarette_ki_tarah/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2017-mubarakan/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2012-dangerous_ishq/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2012-luv_shuv_tey_chicken_khurana/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2015-masaan/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2017-kaalakaandi/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2010-toonpur_ka_super_hero/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2015-main_aur_charles/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2010-we_are_family/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2014-the_shaukeens/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2013-ramaiya_vastavaiya/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2014-dekh_tamasha_dekh/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2017-noor/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2009-kurbaan/')
# ('new_frames_folder_path', "/home/mayank/Desktop/gender-bias-detection/trailer-frames/2013-i_don't_luv_u/")
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2017-ranchi_diaries/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2008-black_and_white/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2013-lootera/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2017-chef/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2016-tum_bin_2/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2016-rebellious_flower/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2012-agent_vinod/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2017-laali_ki_shaadi_mein_laaddoo_deewana/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2017-love_you_family/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2014-fugly/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2014-mumbai_125_km_/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2015-kuch_kuch_locha_hai/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2010-robot/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2011-patiala_house/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2015-nh10/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2014-super_nani/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2014-ungli/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2011-saheb_biwi_aur_gangster/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2011-yeh_faasley/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2009-straight/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2016-teraa_surroor/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2011-no_one_killed_jessica/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2015-hunterrr/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2013-the_lunchbox/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2014-zed_plus/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2014-rang_rasiya/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2011-zokkomon/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2010-shahrukh_bola_"khoobsurat_hai_tu"/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2011-shakal_pe_mat_ja/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2009-99/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2016-fan/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2009-all_the_best:_fun_begins/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2017-jagga_jasoos/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2009-luck/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2014-hawaa_hawaai/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2015-dil_dhadakne_do/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2017-raag_desh:_birth_of_a_nation/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2015-hamari_adhuri_kahani/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2014-lingaa/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2013-yamla_pagla_deewana_2/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2012-kahaani/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2014-bewakoofiyaan/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2011-stanley_ka_dabba/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2011-shor_in_the_city/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2016-luv_u_alia/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2013-gori_tere_pyaar_mein/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2013-dehraadumm_diary/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2017-jolly_llb_2/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2017-patel_ki_punjabi_shaadi/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2012-chhodo_kal_ki_baatein/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2009-quick_gun_murugun/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2014-station:_the_flim/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2016-freaky_ali/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2017-chauhar/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2017-poorna:_courage_has_no_limit/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2017-mukti_bhawan/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2017-meri_pyaari_bindu/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2015-the_silent_heroes/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2009-de_dana_dan/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2015-pyaar_ka_punchname_2/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2014-action_jackson/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2013-prague/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2012-blood_money/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2016-neerja/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2017-commando_2/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2010-rokkk/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2016-befikre/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2016-saat_uchakkey/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2013-bandook/')
# ('new_frames_folder_path', "/home/mayank/Desktop/gender-bias-detection/trailer-frames/2009-what's_your_rashee?/")
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2011-yeh_dooriyan/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2010-guzaarish/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2008-rock_on!!/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2012-khiladi_786/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2016-moh_maya_money/')
# ('new_frames_folder_path', "/home/mayank/Desktop/gender-bias-detection/trailer-frames/2012-valentine's_night/")
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2015-rahasya/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2016-saansein/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2010-badmaash_company/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2017-mantostaan/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2015-international_hero/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2015-dum_laga_ke_haisha/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2016-mohenjo_daro/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2016-phobia/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2010-kushti/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2011-double_dhamaal/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2015-mere_genie_uncle/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2011-bin_bulaye_baraati/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2011-mere_brother_in_dulhan/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2010-phoonk_2/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2015-coffee_bloom/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2014-3_a/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2010-teen_patti/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2017-rangoon/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2011-that_girl_in_yellow_boots/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2017-parmanu:_the_story_of_pokhran/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2015-singh_is_bliing/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2010-hello_darling/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2013-dhoom_3/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2013-bajatey_raho/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2014-kochadaiiyaan/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2012-ek_main_aur_ekk_tu/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2009-dil_bole_hadippa!/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2015-prem_ratan_dhan_payo/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2015-crazy_cukkad_family/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2016-baar_baar_dekho/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2017-ek_thi_rani_aisi_bhi/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2010-ek_second/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2017-naam_shabana/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2013-chor_chor_super_chor/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2009-jail/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2010-ishqiya/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2010-shaapit/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2016-fredrick/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2013-table_no/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2012-aiyyaa/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2010-striker/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2012-jab_tak_hai_jaan/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2014-gunday/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2013-inkaar/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2013-david/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2012-jalpari:_the_desert_mermaid/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2014-main_tera_hero/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2014-tamanchey/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2015-rolling_dream/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2010-do_dooni_chaar/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2012-tere_naal_love_ho_gaya/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2017-bachche_kachche_sachche/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2015-chal_guru_ho_ja_shuru/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2013-krrish_3/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2013-what_the_fish/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2013-3g/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2015-sabki_bajegi_band/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2013-phata_poster_nikla_hero/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2013-maazii/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2011-united_six/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2014-darr_@_the_mall/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2014-purani_jeans/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2015-p_se_pm_tak/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2015-margarita_with_a_straw/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2017-babumoshai_bandookbaaz/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2014-main_aur_mr/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2016-raaz_reboot/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2017-toilet:_ek_prem_katha/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2016-love_games/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2010-maalik_ek/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2014-singham_returns/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2010-aakrosh/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2016-rough_book/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2013-madras_cafe/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2010-khelein_hum_jee_jaan_sey/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2011-bhindi_baazaar_inc/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2016-raman_raghav_2/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2009-kambakkht_ishq/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2017-the_rally/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2011-kaccha_limbo/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2009-billu/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2010-udaan/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2016-jai_gangaajal/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2014-mad_about_dance/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2009-kaminey/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2015-mumbai_can_dance_saala/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2011-love_u/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2014-pizza/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2014-queen/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2015-uvaa/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2015-roy/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2009-wanted/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2017-the_ghazi_attack/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2014-kuku_mathur_ki_jhand_ho_gayi/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2016-junooniyat/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2008-jodhaa_akbar/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2011-kuchh_luv_jaisaa/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2015-hero/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2009-8_x_10_tasveer/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2009-fruit_and_nut/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2014-samrat_&_co/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2009-agyaat/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2010-lahore/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2010-golmaal_3/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2016-nil_battey_sannata/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2013-d_day/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2015-tanu_weds_manu_returns/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2014-humpty_sharma_ki_dulhania/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2016-dangal/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2008-a_wednesday!/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2015-badlapur/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2015-take_it_easy/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2017-halg_girlfriend/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2015-bumber_draw/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2013-main_krishna_hoon/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2011-rascals/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2010-a_flat/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2009-shortkut/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2014-bhoothnath_returns/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2013-murder_3/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2008-jumbo/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2012-from_sydney_with_love/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2009-kisaan/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2016-do_lafzon_ki_kahani/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2015-piku/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2011-impatient_vivek/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2016-kaptaan/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2015-ek_pahel_leela/')
# ('new_frames_folder_path', "/home/mayank/Desktop/gender-bias-detection/trailer-frames/2017-hanuman:_da'_damdaar/")
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2012-teri_meri_kahaani/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2016-happy_bhaag_jayegi/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2017-munna_michael/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2014-yeh_hai_bakrapur/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2014-w/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2016-mirzya/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2012-kyaa_super_kool_hai_hum/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2016-shortcut_safari/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2011-dum_maaro_dum/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2017-bareilly_ki_barfi/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2008-mere_baap_pehle_aap/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2017-ok_jaanu/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2010-raavan/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2010-paathshaala/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2016-aligarh/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2010-knock_out/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2014-abhinay_chakra/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2016-fuddu/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2013-siddharth/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2012-login/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2015-angry_indian_goddesses/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2012-delhi_safari/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2011-shagird/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2011-shabhri/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2015-yaara_silly_silly/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2012-shirin_farhad_ki_toh_nikal_padi/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2010-once_upon_a_time_in_mumbai/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2011-chalo_dilli/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2016-veerappan/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2017-poster_boys/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2009-aagey_se_right/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2017-judwaa_2/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2010-tum_milo_toh_sahi/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2017-gurgaon/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2015-sorry_daddy/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2016-1920_london/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2016-dear_dad/')
# ('new_frames_folder_path', "/home/mayank/Desktop/gender-bias-detection/trailer-frames/2009-let's_dance/")
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2013-shudhh_desi_romance/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2009-delhi-6/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2008-good_luck!/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2009-radio/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2013-bullett_raja/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2017-tiger_zinda_hai/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2015-ishqedarriyaan/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2016-traffic/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2016-motu_patlu:_king_of_kings/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2012-paan_singh_tomar/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2014-dishkiyaoon/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2010-aashayein/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2012-maximum/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2016-m/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2015-dharam_sankat_mein/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2010-milenge_milenge/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2011-naughty_@_40/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2015-mr/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2009-daddy_cool/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2010-right_yaaa_wrong/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2014-happy_new_year/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2008-superstar/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2013-nautanki_saala/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2016-azhar/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2010-tere_bin_laden/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2015-tevar/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2010-the_hangman/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2008-mehbooba/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2011-my_friend_pinto/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2016-saala_khadoos/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2012-say_yes_to_love/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2017-irada/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2012-ferrari_ki_sawaari/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2008-gumnaam_-_the_mystery/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2015-phantom/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2011-don_2:_the_chase_continues/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2010-bhindi_baazaar_inc/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2008-dasvidaniya/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2014-paranthe_wali_gali/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2016-airlift/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2009-gulaal/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2017-anaarkali_of_aarah/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2014-2_states/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2017-indu_sarkar/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2010-mirch/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2017-chakallaspur/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2016-ok_mein_dhokhe/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2014-badlapur_boys/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2012-will_you_marry_me?/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2012-bittoo_boss/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2017-jab_harry_met_sejal/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2009-ajab_prem_ki_ghazab_kahani/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2017-trapped/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2010-break_ke_baad/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2010-the_film_emotional_atyachar/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2016-madaari/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2008-summer_2007/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2017-guest_in_london/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2010-dabangg/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2013-sixteen/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2016-sanam_teri_kasam/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2015-badmashiyaan/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2014-kick/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2013-romeo/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2012-tezz/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2014-kill_dil/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2017-sarkar_3/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2014-fireflies/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2015-detective_byomkesh_bakhsy/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2010-atithi_tum_kab_jaoge?/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2016-wazir/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2016-tere_bin_laden:_dead_or_alive/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2015-titli/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2013-horror_story/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2016-dishoom/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2012-dabangg_2/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2012-rush/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2011-zindagi_na_milegi_dobara/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2011-yeh_saali_zindagi/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2008-woodstock_villa/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2010-chance_pe_dance/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2008-haal-e-dil/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2016-kapoor_&_sons/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2012-shanghai/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2008-phoonk/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2017-jeena_isi_ka_naam_hai/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2016-dhanak/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2014-khoobsurat/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2010-click/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2012-makkhi/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2008-ghajini/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2015-dolly_ki_doli/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2017-hindi_medium/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2013-issaq/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2011-phhir/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2013-ship_of_theseus/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2017-haseena_parkar/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2017-dobaara:_see_your_evil/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2017-g_kutta_se/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2011-aazaan/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2016-m_cream/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2017-ajab_singh_ki_gajab_kahani/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2015-abcd_2/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2009-vaada_raha/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2016-the_legend_of_michael_mishra/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2010-lafangey_parindey/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2014-miss_lovely/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2011-warning/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2012-chaalis_chauraasi_4084/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2013-zanjeer/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2014-total_siyapaa/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2008-rab_ne_bana_di_jodi/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2015-court/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2014-honour_killing/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2009-aa_dekhen_zara/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2013-commando-_a_one_man_army/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2016-laal_rang/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2015-msg:_the_messenger/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2016-global_baba/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2016-force_2/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2011-turning_30!!/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2015-i_love_desi/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2014-sholay_3d/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2016-ek_tera_saath/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2013-b/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2017-shubh_mangal_savdhan/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2011-404/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2009-love_aaj_kal/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2008-maharathi/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2010-rakta_charitra_-_ii/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2008-meerbai_not_out/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2015-guddu_rangeela/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2014-ya_rab/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2016-7_hours_to_go/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2015-luckhnowi_ishq/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2012-talaash/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2013-yeh_jawaani_hai_deewani/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2016-mastizaade/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2014-om-dar-ba-dar/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2014-life_is_beautiful!/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2010-road,_movie/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2017-saanjh/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2016-parched/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2008-anamika/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2010-raajneeti/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2012-barfi!/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2017-sweetiee_weds_nri/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2014-hate_story_2/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2010-payback/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2016-chalk_n_duster/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2017-bhoomi/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2011-happy_husbands/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2014-holiday/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2010-pyaar_impossible!/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2011-dhobi_ghat/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2013-ek_thi_daayan/')
# ...
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2008-bombay_to_bangkok/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2011-jo_hum_chalein/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2016-wajah_tum_ho/')
# ('new_frames_folder_path', "/home/mayank/Desktop/gender-bias-detection/trailer-frames/2010-it's_a_wonderful_afterlife/")
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2008-sunday/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2016-jugni/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2017-sachin:_a_billion_dreams/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2009-sikander/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2017-qaidi_band/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2013-boyss_toh_boyss_hai/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2014-bobby_jasoos/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2010-karthik_calling_karthik/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2014-bang_bang!/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2008-jannat/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2016-brahman_naman/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2014-machhli_jal_ki_rani_hai/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2008-bhoothnath/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2008-dostana/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2015-khamoshiyan:_silences_have_secrets/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2014-room_-_the_mystery/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2016-days_of_tafree/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2014-karle_pyaar_karle/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2012-jodi_breakers/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2016-shivaay/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2014-a_decent_arrangement/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2016-ek_kahani_julie_ki/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2015-hey_bro/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2013-anjur_arora_murder_case/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2008-drona/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2010-mr/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2009-aladin/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2017-aa_gaya_hero/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2015-bangistan/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2012-raaz_3/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2011-haunted_-_3d/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2014-entertainment/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2012-cocktail/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2011-shaitan/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2014-shaadi_ke_side_effects/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2015-dirty_politics/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2013-go_goa_gone/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2015-all_is_well/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2010-my_name_is_khan/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2011-game/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2009-bal_ganesh_2/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2015-jazbaa/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2016-dil_toh_deewana_hai/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2008-emi_-_liya_hai_toh_chukana_padega/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2009-blue/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2015-aisa_yeh_jahaan/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2012-student_of_the_year/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2008-kidnap/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2012-housefull_2/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2015-bajirao_mastani/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2010-action_replayy/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2010-hisss/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2013-shree/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2014-ekkees_toppon_ki_salaami/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2013-aashiqui_2/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2008-money_hai_toh_honey_hai/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2016-hai_apna_dil_toh_awara/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2014-bhopal:_a_prayer_for_rain/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2009-firaaq/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2014-lucky_kabootar/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2013-once_upon_a_time_in_mumbai_doobara!/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2015-kis_kisko_pyaar_karoon/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2009-the_stoneman_murders/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2016-akira/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2015-bombay_velvet/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2014-jal/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2008-roadside_romeo/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2010-antardwand/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2008-1920/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2016-ishq_junoon/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2014-youngistaam/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2014-heartless/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2015-gour_hari_dastaan/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2012-fatso!/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2017-yadvi_-_the_dignified_princess/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2012-ghost/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2016-bollywood_diaries/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2015-x/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2015-baby/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2008-mr/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2009-rocket_singh:_salesman_of_the_year/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2017-mom/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2013-mumbai_mirror/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2012-marries_2_america/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2016-tutak_tutak_tutiya/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2016-anna/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2015-barkhaa/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2011-khap/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2014-roar_-_tigers_of_sunderbans/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2014-anuradha/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2010-trump_card/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2008-one_two_three/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2016-dongri_ka_raja/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2017-ittefaq/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2012-heroine/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2016-sultan/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2011-speedy_singhs/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2013-nasha/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2010-soch_lo/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2013-luv_u_soniyo/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2017-a_death_in_the_gunj/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2011-damadamm!/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2010-dulha_mil_gaya/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2015-hawaizaada/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2015-dilwale/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2015-brothers/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2011-ragini_mms/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2014-mumbhai_connection/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2014-gulabi_gang/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2010-sadiyaan/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2014-happy_ending/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2011-desi_boyz/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2011-bubble_gum/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2016-rustom/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2013-john_day/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2017-simran/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2016-ishq_click/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2008-oye_lucky!_lucky_oye!/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2014-titoo_mba/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2011-angel/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2012-arjun:_the_warrior_prince/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2013-aurangzeb/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2008-krazzy_4/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2014-meine_ek_ladki_chaahiye/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2009-wake_up_sid/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2016-banjo/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2014-kahi_hai_mera_pyar/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2015-drishyam/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2015-kajarya/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2009-little_zizou/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2011-murder_2/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2010-the_waiting_room/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2017-behen_hogi_teri/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2011-ra/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2009-luck_by_chance/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2015-welcome_back/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2017-begum_jaan/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2017-phillauri/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2009-new_york/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2012-players/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2013-warning/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2015-ranbanka/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2012-sadda_adda/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2016-loveshhuda/')
# ('new_frames_folder_path', '/home/mayank/Desktop/gender-bias-detection/trailer-frames/2016-housefull_3/')

# %%
df.trailer.value_counts()
# Out:
# 1    880
# 0    123
# Name: trailer, dtype: int64
